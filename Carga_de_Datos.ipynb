# %% [markdown]
# ### +++ Visualización de tabla completa +++

# %%
import pandas as pd

datos = pd.read_csv('avocado.csv',delimiter=',',decimal=".",index_col=1)
print(datos.shape)
datos
# Out:
# (18249, 13)
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# ...

# %% [markdown]
# ### +++ Visualización de las primeras líneas de tabla (suando función head) +++

# %%
import pandas as pd 

datos = pd.read_csv("avocado.csv",delimiter=',',decimal=".",index_col=1)
#Para cambiar el orden de las columnas, modificamos el valor de: index_col 

datos.head(20)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# 2015-11-22           5          1.26      55979.78  1184.27   48067.99
# 2015-11-15           6          0.99      83453.76  1368.92   73672.72
# 2015-11-08           7          0.98     109428.33   703.75  101815.36
# 2015-11-01           8          1.02      99811.42  1022.15   87315.57
# 2015-10-25           9          1.07      74338.76   842.40   64757.44
# 2015-10-18          10          1.12      84843.44   924.86   75595.85
# 2015-10-11          11          1.28      64489.17  1582.03   52677.92
# ...

# %% [markdown]
# Nota: Para poder responder a la 2da pregunta que se ecuentra al final de este código, se puso como argumento "20"

# %% [markdown]
# ### +++ Combinaciones de columnas y datos +++

# %%
datos.iloc[[1,2,3],[4,5,6]]
# Out:
#                  4225    4770  Total Bags
# Date
# 2015-12-20   44638.81   58.33     9505.56
# 2015-12-13  109149.67  130.50     8145.35
# 2015-12-06   71976.41   72.58     5811.16

# %% [markdown]
# ### +++ Usando la función "describe" +++

# %%
print(datos.describe())
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# ## +++ Preguntas +++

# %% [markdown]
# ###### 1. ¿Cuántos objetos hay?
#
# Hay: 18 249 objetos

# %% [markdown]
# ###### 2. ¿Cuál es el valor de la variable 2 del objeto 15?
#
# El valor es: 1.33

# %% [markdown]
# ###### 3. ¿Cuál es el mínimo y máximo de la variable 3?

# %%
print("================Máximos===============")
print(datos.max(numeric_only=True))
print("\n================Mínimos===============")
print(datos.min(numeric_only=True))
# Out:
# ================Máximos===============
# Unnamed: 0            52.00
# AveragePrice           3.25
# Total Volume    62505646.52
# 4046            22743616.17
# 4225            20470572.61
# 4770             2546439.11
# Total Bags      19373134.37
# Small Bags      13384586.80
# Large Bags       5719096.61
# XLarge Bags       551693.65
# year                2018.00
# dtype: float64
#
# ================Mínimos===============
# Unnamed: 0         0.00
# AveragePrice       0.44
# Total Volume      84.56
# 4046               0.00
# 4225               0.00
# 4770               0.00
# Total Bags         0.00
# Small Bags         0.00
# Large Bags         0.00
# XLarge Bags        0.00
# year            2015.00
# dtype: float64

# %% [markdown]
# **********************************
# Máximo = 62505646.52
# **********************************
# Mínimo = 84.56
